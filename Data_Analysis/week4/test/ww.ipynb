# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/CODEs/Classroom/Data-Analysis (Lab)/week4/test/housing.csv")

df[df.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df[["PoolQC"]].fillna(9)
# Out:
#      PoolQC
# 0         9
# 1         9
# 2         9
# 3         9
# 4         9
# ...     ...
# 1455      9
# 1456      9
# 1457      9
# 1458      9
# 1459      9
#
# [1460 rows x 1 columns]

# %%
df[["LotFrontage"]].fillna(df["LotFrontage"].mean())
# Out:
#       LotFrontage
# 0            65.0
# 1            80.0
# 2            68.0
# 3            60.0
# 4            84.0
# ...           ...
# 1455         62.0
# 1456         85.0
# 1457         66.0
# 1458         68.0
# 1459         75.0
#
# [1460 rows x 1 columns]

# %%
plt.hist(df["SalePrice"],bins=10,color = "yellow",edgecolor="black")
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df["GrLivArea"],df["SalePrice"],color="red")

# %%
df_Housestyle_counts = df.groupby(["HouseStyle"])["SalePrice"].count()
plt.pie(df_Housestyle_counts,labels=df_Housestyle_counts.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x22d1dbc66c0>,
# ...
#  [Text(1.0401560295664363, 0.3578762833111286, '1.5Fin'),
#   Text(0.846356323889459, 0.7026243470107775, '1.5Unf'),
#   Text(-0.7206719709999103, 0.8310426644975002, '1Story'),
#   Text(-0.8248090635584823, -0.727798054869467, '2.5Fin'),
#   Text(-0.7943730155992614, -0.7609017755845597, '2.5Unf'),
#   Text(0.19075395563499298, -1.083334172086159, '2Story'),
#   Text(1.0297394841827836, -0.3868288959152029, 'SFoyer'),
#   Text(1.0892582388000451, -0.1533508695972213, 'SLvl')])
