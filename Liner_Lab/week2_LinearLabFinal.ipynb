# %%
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt
def transform(A,X):
    return np.dot(A,X)


# A=np.array([[0.5,0],[0,0.5]])
# B=np.array([[2,0],[0,2]])

# Creating equally spaced 100 data in range 0 to 2*pi
theta = np.linspace(0, 2 * np.pi, 100)
# Generating x and y data
xvals = 16 * ( np.sin(theta) ** 3 )+20
yvals = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)+17
X = np.row_stack((xvals, yvals))
plt.axis("equal")
plt.grid(True)
for n in range(20) :
    A=np.array([[n*0.1,0],[0,n*0.1]])
    ax=transform(A,X)
    # bx=transform(B,X)
    # plt.plot(X[0,:],X[1,:],"r")
    plt.plot(ax[0,:],ax[1,:],"g")
# plt.plot(bx[0,:],bx[1,:],"b")
plt.show()

# %% [markdown]
# # 1 (A)

# %%
import numpy as np
import matplotlib.pyplot as plt
def transform(A,X):
    return np.dot(A,X)

A=np.array([[-1,0],[0,1]])
C=np.array([[1,0],[0,-1]])
# Creating equally spaced 100 data in range 0 to 2*pitheta = np.linspace(0, 2 * np.pi, 100)

 # Generating x and y data
xvals = 16 * ( np.sin(theta) ** 3 )+20
yvals = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)+17
X = np.row_stack((xvals, yvals))

plt.axis("equal")
plt.grid(True)
ax=transform(A,X)
cx=transform(C,ax)
plt.plot(X[0,:],X[1,:],"r")
plt.plot(ax[0,:],ax[1,:],"g")
plt.plot(cx[0,:],cx[1,:],"y")
plt.show()

# %% [markdown]
# # 1 (b)

# %%
import numpy as np
import matplotlib.pyplot as plt
def transform(A,X):
    return np.dot(A,X)

A=np.array([[-1,0],[0,1]])
t = np.pi
B=np.array([[np.cos(t),-np.sin(t)],[np.sin(t),np.cos(t)]])
# Creating equally spaced 100 data in range 0 to 2*pitheta = np.linspace(0, 2 * np.pi, 100)

 # Generating x and y data
xvals = 16 * ( np.sin(theta) ** 3 )+20
yvals = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)+17
X = np.row_stack((xvals, yvals))

plt.axis("equal")
plt.grid(True)
ax=transform(B,X)
    # plt.plot(X[0,:],X[1,:],"r")
plt.plot(ax[0,:],ax[1,:],"b")
plt.plot(X[0,:],X[1,:],"r")
# plt.plot(bx[0,:],bx[1,:],"b")
plt.show()

# %% [markdown]
# # 2 (b)

# %%
import numpy as np
import matplotlib.pyplot as plt
def transform(A,X):
    return np.dot(A,X)
t = np.pi
A=np.array([[np.cos(t),-np.sin(t)],[np.sin(t),np.cos(t)]])

# Creating equally spaced 100 data in range 0 to 2*pitheta = np.linspace(0, 2 * np.pi, 100)

 # Generating x and y data
xvals = 16 * ( np.sin(theta) ** 3 )+20
yvals = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)+17
X = np.row_stack((xvals, yvals))

plt.axis("equal")
plt.grid(True)

ax=transform(A,X)
plt.plot(X[0,:],X[1,:],"r")
plt.plot(ax[0,:],ax[1,:],"g")
plt.show()

# %% [markdown]
# # 2 (a)

# %%
import numpy as np
import matplotlib.pyplot as plt
def transform(A,X):
    return np.dot(A,X)
t = np.pi/6
A=np.array([[np.cos(t),-np.sin(t)],[np.sin(t),np.cos(t)]])

# Creating equally spaced 100 data in range 0 to 2*pitheta = np.linspace(0, 2 * np.pi, 100)

 # Generating x and y data
xvals = 16 * ( np.sin(theta) ** 3 )+20
yvals = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)+17
X = np.row_stack((xvals, yvals))

plt.axis("equal")
plt.grid(True)
# n+1 only
for n in range(7) : 
    ax=transform(np.linalg.matrix_power(A,n),X)
    plt.plot(X[0,:],X[1,:],"r")
    plt.plot(ax[0,:],ax[1,:],"g")
plt.show()

# %% [markdown]
# # 3 (a)

# %%
import numpy as np
import matplotlib.pyplot as plt
def transform(A,X):
    return np.dot(A,X)
t = np.pi/3

A=np.array([[-1,0],[0,1]])
B=np.array([[np.cos(t),-np.sin(t)],[np.sin(t),np.cos(t)]])
# Creating equally spaced 100 data in range 0 to 2*pitheta = np.linspace(0, 2 * np.pi, 100)

 # Generating x and y data
xvals = 16 * ( np.sin(theta) ** 3 )+20
yvals = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)+17
X = np.row_stack((xvals, yvals))

plt.axis("equal")
plt.grid(True)

ax=transform(A,X)
bx = transform(B,ax)
plt.plot(X[0,:],X[1,:],"r")
plt.plot(ax[0,:],ax[1,:],"g")
plt.plot(bx[0,:],bx[1,:],"b")
plt.show()

# %% [markdown]
# # 3 (b)

# %%
import numpy as np
import matplotlib.pyplot as plt
def transform(A,X):
    return np.dot(A,X)
t = np.pi/3

A=np.array([[-1,0],[0,1]])
B=np.array([[np.cos(t),-np.sin(t)],[np.sin(t),np.cos(t)]])
# Creating equally spaced 100 data in range 0 to 2*pitheta = np.linspace(0, 2 * np.pi, 100)

 # Generating x and y data
xvals = 16 * ( np.sin(theta) ** 3 )+20
yvals = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)+17
X = np.row_stack((xvals, yvals))

plt.axis("equal")
plt.grid(True)

bx = transform(B,X)
ax=transform(A,bx)
plt.plot(X[0,:],X[1,:],"r")
plt.plot(ax[0,:],ax[1,:],"g")
plt.plot(bx[0,:],bx[1,:],"b")
plt.show()

# %%
# importing numpy package
import numpy as np
# importing matplotlib package
import matplotlib.pyplot as plt
def transform(A,X):
    return np.dot(A,X)

ax = plt.figure().add_subplot(projection='3d') #set up for 3D plot

# Prepare data X as a 3xn matrix
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)
X=np.row_stack((x,y,z))

for n in range(12):
    t=n*np.pi/4 # radius
    A=np.array([[np.cos(t),-np.sin(t),0],[np.sin(t),np.cos(t),0], [0,0,1]])
    Tx=transform(A,X)
    ax.plot3D(Tx[0,:],Tx[1,:], Tx[2,:])
plt.show()
